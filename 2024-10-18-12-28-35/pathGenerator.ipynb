# %%
import os
import sys
import json
if 'SUMO_HOME' in os.environ:
    sys.path.append(os.path.join(os.environ['SUMO_HOME'], 'tools'))
import sumolib
import importlib
import LLAMAconnect
import subprocess
import shutil
from pprint import pprint
import random

# %%
net = sumolib.net.readNet('osm.net.xml')
parkingAreas = list(sumolib.output.parse('park.add.xml', "parkingArea"))

# %%
## Script for generating alternative routes
duaiterate_path = "/usr/share/sumo/tools/assign/duaIterate.py"
def getArgs(net_path, trips_path, additional_path, iterations):
    args = [
        "-n", net_path,
        "-t", trips_path,
        "--additional", additional_path,
        "duarouter--additional-files", additional_path,
        "-l", str(iterations)
    ]
    return args

# %%
# Latitude e longitude de locais de interesse
coords = {
    "IC": (-22.813344, -47.063667),
    "FEEC": (-22.820788, -47.066489),
    "HOME": (-22.823781, -47.074111),
    "RU": (-22.817327, -47.071338),
    "IB": (-22.819330, -47.068836),
    "RS": (-22.815302, -47.062603),
    "BC": (-22.816370, -47.071218),
    "FEF": (-22.815240, -47.072680),
    "IFGW": (-22.817940, -47.067007),
    "IMECC": (-22.816385, -47.068329),
    "RA": (-22.822440, -47.065231),
    "IQ": (-22.817794, -47.068351),
    "FEQ": (-22.820118, -47.065556),
    "IG": (-22.813727, -47.069196)
}

# %%
radius = 150

# %%
def has_parking_spot(lanes, parkingAreas):
    # Example of parkingArea:
    # <parkingArea id="pa-1046248579#0" lane="-1046248579#0_0" roadsideCapacity="94" length="5.00"/>
    # Returns parkingArea id if there is a parking spot in the lane
    lane_ids = [lane.getID() for lane in lanes]
    for park in parkingAreas:
        if park.lane in lane_ids:
            return park.id
    return False

# %%
def getClosestEdges(lat, lon, radius, maxEdges=10):
    # Gets the 10 closest edges to the given lat, lon
    x, y = net.convertLonLat2XY(lon, lat)
    edges = net.getNeighboringEdges(x, y, radius)
    closestEdges = []
    if (len(edges) > 0):
        distanceAndEdges = sorted([(dist, edge) for edge, dist in edges], key=lambda x:x[0])

        ## Checking if the edge found can be used by passenger car
        for dist, edge in distanceAndEdges:
            if edge.allows('passenger'):
                closestEdges.append(edge)

    if len(edges) == 0:
        print(f'No edges found for {lat}, {lon}')
    return closestEdges

# %%
def getParkingSpot(lat, lon, radius, parkingAreas):
    # Get the parking spot closest to the given lat, lon
    # Used to set stops for the vehicles

    edges = getClosestEdges(lat, lon, radius)
    # Look for parking spots
    for i in range(len(edges)):
        parking_spot = has_parking_spot(edges[i].getLanes(), parkingAreas)
        if parking_spot:
            return parking_spot
    print("No parking spot found:", lat, lon)
    return None

# %%
def getPath(location_time_list, parkingAreas):
    # All that is needed to create the trip are the stops (parking areas) and the start and end edges.
    # The duarouter is responsible for finding the path between the edges going through the stops.
    # Here, we get the edges and stops that are going to be sent to LLAMA to create the trip.

    # 'coordinates' is a list of tuples with the latitude and longitude of the points of interest, for example IC, FEEC, IC means that
    # the vehicle will start from IC, stop at a parking lot close to FEEC, and then back to IC.
    # The first and last coordinates should be edges and the others should be parking spots.

    # Departure for 7 is 0, 8 is 100, 9 is 200 and so on
    stop_durations = []
    departures = list(location_time_list.keys())
    stop_durations.append(-1) # Indicates this is an edge and not a parking spot

    path = []
    locations = list(location_time_list.values())
    home = getClosestEdges(*locations[0], radius)[0].getID()
    path.append(home)
    
    for i in range(1, len(locations)-1):
        stop_durations.append(100 * (departures[i] - departures[i - 1]))
        path.append(getParkingSpot(*locations[i], radius, parkingAreas))
    
    path.append(home)
    stop_durations.append(-1)
    
    return path, stop_durations

# %%
def pathToXML(path, vehicleID, veh_type, departure_time, stop_durations):
    # Converts the path to the XML format that LLAMA understands
    xml = f'<trip id="{vehicleID}" type="{veh_type}" depart="{departure_time}" from="{path[0]}" to="{path[-1]}">\n'
    for i in range(1, len(path)-1):
        xml += f'\t<stop parkingArea="{path[i]}" duration="{stop_durations[i]}"/>\n'
    xml += '</trip>'
    return xml

# %% [markdown]
# Getting the routine for the students described

# %%
student_info = "A Computer Engineering student, a Computer Science student, two Biology students and one Physics student. One of the biology students loves sports and other biology does not have classes all day long. The Computer Engineering and Computer Science students have lunch and dinner at RU."
importlib.reload(LLAMAconnect)
response = LLAMAconnect.getResponse_trip(student_info)
json_response = json.loads(response)
print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[75], line 3
#       1 student_info = "A Computer Engineering student, a Computer Science student, two Biology students and one Physics student. One of the biology students loves sports and other biology does not have classes all day long. The Computer Engineering and Computer Science students have lunch and dinner at RU."
#       2 importlib.reload(LLAMAconnect)
# ----> 3 response = LLAMAconnect.getResponse_trip(student_info)
#       4 json_response = json.loads(response)
#       5 print(response)
#
# File ~/Sumo/completo/LLAMAconnect.py:81, in getResponse_trip(student_info)
#      44 instructions_content = (f"Plan the information of the following student: {student_info}. Students do not have classes during lunch and dinner time"
#      45                         )
#      46 message = [
#      47     {
#      48         "role": "system",
#    (...)
#      79     }
#      80 ]
# ---> 81 chat_completion = client.chat.completions.create(messages=message, model="llama3-8b-8192", temperature=0.4, response_format={"type": "json_object"})
#      83 return chat_completion.choices[0].message.content
#
# File ~/.local/lib/python3.10/site-packages/groq/resources/chat/completions.py:287, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     146 def create(
#     147     self,
#     148     *,
#    (...)
#     175     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     176 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     177     """
#     178     Creates a model response for the given chat conversation.
#     179
#    (...)
#     285       timeout: Override the client-level default timeout for this request, in seconds
#     286     """
# --> 287     return self._post(
#     288         "/openai/v1/chat/completions",
#     289         body=maybe_transform(
#     290             {
#     291                 "messages": messages,
#     292                 "model": model,
#     293                 "frequency_penalty": frequency_penalty,
#     294                 "function_call": function_call,
#     295                 "functions": functions,
#     296                 "logit_bias": logit_bias,
#     297                 "logprobs": logprobs,
#     298                 "max_tokens": max_tokens,
#     299                 "n": n,
#     300                 "parallel_tool_calls": parallel_tool_calls,
#     301                 "presence_penalty": presence_penalty,
#     302                 "response_format": response_format,
#     303                 "seed": seed,
#     304                 "stop": stop,
#     305                 "stream": stream,
#     306                 "temperature": temperature,
#     307                 "tool_choice": tool_choice,
#     308                 "tools": tools,
#     309                 "top_logprobs": top_logprobs,
#     310                 "top_p": top_p,
#     311                 "user": user,
#     312             },
#     313             completion_create_params.CompletionCreateParams,
#     314         ),
#     315         options=make_request_options(
#     316             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     317         ),
#     318         cast_to=ChatCompletion,
#     319         stream=stream or False,
#     320         stream_cls=Stream[ChatCompletionChunk],
#     321     )
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:1244, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1230 def post(
#    1231     self,
#    1232     path: str,
#    (...)
#    1239     stream_cls: type[_StreamT] | None = None,
#    1240 ) -> ResponseT | _StreamT:
#    1241     opts = FinalRequestOptions.construct(
#    1242         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1243     )
# -> 1244     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1036         err.response.read()
#    1038     log.debug("Re-raising status error")
# -> 1039     raise self._make_status_error_from_response(err.response) from None
#    1041 return self._process_response(
#    1042     cast_to=cast_to,
#    1043     options=options,
#    (...)
#    1047     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1048 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "trip1": {\n      "7": {"location": "HOME", "activity": "wake up"},\n      "8": {"location": "FEEC", "activity": "class"},\n      "9": {"location": "FEEC", "activity": "class"},\n      "10": {"location": "FEEC", "activity": "class"},\n      "11": {"location": "FEEC", "activity": "class"},\n      "12": {"location": "RU", "activity": "lunch"},\n      "13": {"location": "BC", "activity": "study"},\n      "14": {"location": "FEEC", "activity": "class"},\n      "15": {"location": "FEEC", "activity": "class"},\n      "16": {"location": "FEEC", "activity": "class"},\n      "17": {"location": "FEEC", "activity": "class"},\n      "18": {"location": "RU", "activity": "dinner"},\n      "19": {"location": "HOME", "activity": "relax"},\n      "20": {"location": "HOME", "activity": "sleep"}\n   }\n},\n{\n   "trip2": {\n      "7": {"location": "HOME", "activity": "wake up"},\n      "8": {"location": "IC", "activity": "class"},\n      "9": {"location": "IC", "activity": "class"},\n      "10": {"location": "IC", "activity": "class"},\n      "11": {"location": "IC", "activity": "class"},\n      "12": {"location": "RU", "activity": "lunch"},\n      "13": {"location": "BC", "activity": "study"},\n      "14": {"location": "IC", "activity": "class"},\n      "15": {"location": "IC", "activity": "class"},\n      "16": {"location": "IC", "activity": "class"},\n      "17": {"location": "IC", "activity": "class"},\n      "18": {"location": "RU", "activity": "dinner"},\n      "19": {"location": "HOME", "activity": "relax"},\n      "20": {"location": "HOME", "activity": "sleep"}\n   }\n},\n{\n   "trip3": {\n      "7": {"location": "HOME", "activity": "wake up"},\n      "8": {"location": "IB", "activity": "class"},\n      "9": {"location": "IB", "activity": "class"},\n      "10": {"location": "IB", "activity": "class"},\n      "11": {"location": "IB", "activity": "class"},\n      "12": {"location": "RA", "activity": "lunch"},\n      "13": {"location": "BC", "activity": "study"},\n      "14": {"location": "IB", "activity": "class"},\n      "15": {"location": "IB", "activity": "class"},\n      "16": {"location": "IB", "activity": "class"},\n      "17": {"location": "IB", "activity": "class"},\n      "18": {"location": "RS", "activity": "dinner"},\n      "19": {"location": "FEF", "activity": "sports"},\n      "20": {"location": "HOME", "activity": "sleep"}\n   }\n},\n{\n   "trip4": {\n      "7": {"location": "HOME", "activity": "wake up"},\n      "8": {"location": "IB", "activity": "class"},\n      "9": {"location": "IB", "activity": "class"},\n      "10": {"location": "IB", "activity": "class"},\n      "11": {"location": "IB", "activity": "class"},\n      "12": {"location": "RA", "activity": "lunch"},\n      "13": {"location": "BC", "activity": "study"},\n      "14": {"location": "HOME", "activity": "free time"},\n      "15": {"location": "BC", "activity": "study"},\n      "16": {"location": "BC", "activity": "study"},\n      "17": {"location": "BC", "activity": "study"},\n      "18": {"location": "RS", "activity": "dinner"},\n      "19": {"location": "HOME", "activity": "relax"},\n      "20": {"location": "HOME", "activity": "sleep"}\n   }\n},\n{\n   "trip5": {\n      "7": {"location": "HOME", "activity": "wake up"},\n      "8": {"location": "IFGW", "activity": "class"},\n      "9": {"location": "IFGW", "activity": "class"},\n      "10": {"location": "IFGW", "activity": "class"},\n      "11": {"location": "IFGW", "activity": "class"},\n      "12": {"location": "RU", "activity": "lunch"},\n      "13": {"location": "BC", "activity": "study"},\n      "14": {"location": "IFGW", "activity": "class"},\n      "15": {"location": "IFGW", "activity": "class"},\n      "16": {"location": "IFGW", "activity": "class"},\n      "1 ...

# %%
student_info = "10 students of any course. Create different trips for each one, there should be 50 trips and be creative, try to define different activies for the students."
importlib.reload(LLAMAconnect)
response = LLAMAconnect.getResponse_trip(student_info)
json_response = json.loads(response)
print(response)
# Out:
# {
#    "trip1": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IC", "activity": "study"},
#       "9": {"location": "IC", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IFGW", "activity": "study"},
#       "18": {"location": "RU", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip2": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IMECC", "activity": "study"},
#       "9": {"location": "IMECC", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "IMECC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IG", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip3": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IQ", "activity": "study"},
#       "9": {"location": "IQ", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IQ", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IB", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip4": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "FEQ", "activity": "study"},
#       "9": {"location": "FEQ", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "FEQ", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip5": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "FEEC", "activity": "study"},
#       "9": {"location": "FEEC", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "FEEC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip6": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IG", "activity": "study"},
#       "9": {"location": "IG", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "IG", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip7": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IB", "activity": "study"},
#       "9": {"location": "IB", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IB", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IQ", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip8": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IFGW", "activity": "study"},
#       "9": {"location": "IFGW", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "IFGW", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip9": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IMECC", "activity": "study"},
#       "9": {"location": "IMECC", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IMECC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IG", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip10": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "FEEC", "activity": "study"},
#       "9": {"location": "FEEC", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "FEEC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip11": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IG", "activity": "study"},
#       "9": {"location": "IG", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IG", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip12": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IB", "activity": "study"},
#       "9": {"location": "IB", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IB", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IQ", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip13": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IFGW", "activity": "study"},
#       "9": {"location": "IFGW", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "IFGW", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip14": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IMECC", "activity": "study"},
#       "9": {"location": "IMECC", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IMECC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IG", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip15": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "FEEC", "activity": "study"},
#       "9": {"location": "FEEC", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "FEEC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip16": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IG", "activity": "study"},
#       "9": {"location": "IG", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IG", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip17": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IB", "activity": "study"},
#       "9": {"location": "IB", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IB", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IQ", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip18": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IFGW", "activity": "study"},
#       "9": {"location": "IFGW", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "IFGW", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IMECC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip19": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "IMECC", "activity": "study"},
#       "9": {"location": "IMECC", "activity": "study"},
#       "10": {"location": "RU", "activity": "breakfast"},
#       "11": {"location": "IMECC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RU", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IG", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    },
#    "trip20": {
#       "7": {"location": "HOME", "activity": "wake up"},
#       "8": {"location": "FEEC", "activity": "study"},
#       "9": {"location": "FEEC", "activity": "study"},
#       "10": {"location": "RA", "activity": "breakfast"},
#       "11": {"location": "FEEC", "activity": "study"},
#       "12": {"location": "BC", "activity": "study"},
#       "13": {"location": "BC", "activity": "study"},
#       "14": {"location": "RA", "activity": "lunch"},
#       "15": {"location": "BC", "activity": "study"},
#       "16": {"location": "BC", "activity": "study"},
#       "17": {"location": "IC", "activity": "study"},
#       "18": {"location": "RS", "activity": "dinner"},
#       "19": {"location": "HOME", "activity": "relax"},
#       "20": {"location": "HOME", "activity": "sleep"}
#    }
# }

# %% [markdown]
# Generating different houses for students based on a random number generator in the where students might live

# %%
def getHome():
    # top right -22.815539, -47.076272
    # top left: -22.818517, -47.079520
    # bottom left: -22.826410, -47.072591
    # bottom right: -22.823439, -47.068828
    X_MIN = 22815539
    X_MAX = 22826410
    Y_MIN = 47068828
    Y_MAX = 47079520
    while True:
        random_x = random.randint(X_MIN, X_MAX)
        random_y = random.randint(Y_MIN, Y_MAX)
        lat = - random_x / 10**6
        lon = - random_y / 10**6
        if (lat, lon) in coords.values():
            continue
        break
    return lat, lon

# %% [markdown]
# Getting the latitude and longitude for each of the locations

# %%
location_time_list = []
for j in range(len(json_response)):
    location_time_list.append({})
for i in range(1, len(json_response) + 1):

    trip = json_response[f'trip{i}']
    home = getHome() # Gets a random home location for each student
    last = home
    location_time_list[i - 1][7] = last
    
    for j in range(1, len(trip)):
        local = trip[f'{j + 7}']['location']

        if local == 'HOME':
            local_coords = home
        else:
            local_coords = coords[trip[f'{j + 7}']['location']]

        if local_coords != last:
            location_time_list[i - 1][j + 7] = local_coords
            last = local_coords

print(len(location_time_list))
pprint(location_time_list)
# Out:
# 20
# [{7: (-22.820626, -47.077545),
#   8: (-22.813344, -47.063667),
#   10: (-22.817327, -47.071338),
#   11: (-22.813344, -47.063667),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.81794, -47.067007),
#   18: (-22.817327, -47.071338),
#   19: (-22.820626, -47.077545)},
#  {7: (-22.816954, -47.075881),
#   8: (-22.816385, -47.068329),
#   10: (-22.82244, -47.065231),
#   11: (-22.816385, -47.068329),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.813727, -47.069196),
#   18: (-22.815302, -47.062603),
#   19: (-22.816954, -47.075881)},
#  {7: (-22.825759, -47.078556),
#   8: (-22.817794, -47.068351),
#   10: (-22.817327, -47.071338),
#   11: (-22.817794, -47.068351),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.81933, -47.068836),
#   18: (-22.815302, -47.062603),
#   19: (-22.825759, -47.078556)},
#  {7: (-22.820225, -47.07844),
#   8: (-22.820118, -47.065556),
#   10: (-22.82244, -47.065231),
#   11: (-22.820118, -47.065556),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.820225, -47.07844)},
#  {7: (-22.822096, -47.071868),
#   8: (-22.820788, -47.066489),
#   10: (-22.817327, -47.071338),
#   11: (-22.820788, -47.066489),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.813344, -47.063667),
#   18: (-22.815302, -47.062603),
#   19: (-22.822096, -47.071868)},
#  {7: (-22.823437, -47.074371),
#   8: (-22.813727, -47.069196),
#   10: (-22.82244, -47.065231),
#   11: (-22.813727, -47.069196),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.823437, -47.074371)},
#  {7: (-22.823274, -47.069329),
#   8: (-22.81933, -47.068836),
#   10: (-22.817327, -47.071338),
#   11: (-22.81933, -47.068836),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.817794, -47.068351),
#   18: (-22.815302, -47.062603),
#   19: (-22.823274, -47.069329)},
#  {7: (-22.816066, -47.075678),
#   8: (-22.81794, -47.067007),
#   10: (-22.82244, -47.065231),
#   11: (-22.81794, -47.067007),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.816066, -47.075678)},
#  {7: (-22.82096, -47.071532),
#   8: (-22.816385, -47.068329),
#   10: (-22.817327, -47.071338),
#   11: (-22.816385, -47.068329),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.813727, -47.069196),
#   18: (-22.815302, -47.062603),
#   19: (-22.82096, -47.071532)},
#  {7: (-22.822019, -47.079427),
#   8: (-22.820788, -47.066489),
#   10: (-22.82244, -47.065231),
#   11: (-22.820788, -47.066489),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.813344, -47.063667),
#   18: (-22.815302, -47.062603),
#   19: (-22.822019, -47.079427)},
#  {7: (-22.823977, -47.073286),
#   8: (-22.813727, -47.069196),
#   10: (-22.817327, -47.071338),
#   11: (-22.813727, -47.069196),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.823977, -47.073286)},
#  {7: (-22.824962, -47.078518),
#   8: (-22.81933, -47.068836),
#   10: (-22.817327, -47.071338),
#   11: (-22.81933, -47.068836),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.817794, -47.068351),
#   18: (-22.815302, -47.062603),
#   19: (-22.824962, -47.078518)},
#  {7: (-22.824845, -47.076443),
#   8: (-22.81794, -47.067007),
#   10: (-22.82244, -47.065231),
#   11: (-22.81794, -47.067007),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.824845, -47.076443)},
#  {7: (-22.820194, -47.079014),
#   8: (-22.816385, -47.068329),
#   10: (-22.817327, -47.071338),
#   11: (-22.816385, -47.068329),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.813727, -47.069196),
#   18: (-22.815302, -47.062603),
#   19: (-22.820194, -47.079014)},
#  {7: (-22.824978, -47.079143),
#   8: (-22.820788, -47.066489),
#   10: (-22.82244, -47.065231),
#   11: (-22.820788, -47.066489),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.813344, -47.063667),
#   18: (-22.815302, -47.062603),
#   19: (-22.824978, -47.079143)},
#  {7: (-22.819707, -47.072148),
#   8: (-22.813727, -47.069196),
#   10: (-22.817327, -47.071338),
#   11: (-22.813727, -47.069196),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.819707, -47.072148)},
#  {7: (-22.816913, -47.069476),
#   8: (-22.81933, -47.068836),
#   10: (-22.817327, -47.071338),
#   11: (-22.81933, -47.068836),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.817794, -47.068351),
#   18: (-22.815302, -47.062603),
#   19: (-22.816913, -47.069476)},
#  {7: (-22.818024, -47.071124),
#   8: (-22.81794, -47.067007),
#   10: (-22.82244, -47.065231),
#   11: (-22.81794, -47.067007),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.816385, -47.068329),
#   18: (-22.815302, -47.062603),
#   19: (-22.818024, -47.071124)},
#  {7: (-22.820619, -47.074031),
#   8: (-22.816385, -47.068329),
#   10: (-22.817327, -47.071338),
#   11: (-22.816385, -47.068329),
#   12: (-22.81637, -47.071218),
#   14: (-22.817327, -47.071338),
#   15: (-22.81637, -47.071218),
#   17: (-22.813727, -47.069196),
#   18: (-22.815302, -47.062603),
#   19: (-22.820619, -47.074031)},
#  {7: (-22.825601, -47.069268),
#   8: (-22.820788, -47.066489),
#   10: (-22.82244, -47.065231),
#   11: (-22.820788, -47.066489),
#   12: (-22.81637, -47.071218),
#   14: (-22.82244, -47.065231),
#   15: (-22.81637, -47.071218),
#   17: (-22.813344, -47.063667),
#   18: (-22.815302, -47.062603),
#   19: (-22.825601, -47.069268)}]

# %% [markdown]
# Taking the locations and turning them into a XML trips, which are written to PATHGEN.trips.xml

# %%
def parseTripXML(location_time_list, parkingAreas, departure_times, veh_types, veh_types_per_student):
    # Creates the XML for the trips
    ids = list(veh_types.keys())
    xml = '<routes xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://sumo.dlr.de/xsd/routes_file.xsd">\n'

    xml += '\n'
    xml += '<!-- Vehicles -->\n'
    for i in range(len(veh_types)):
        id = ids[i]
        veh = veh_types[id]
        xml += f'<vType id="{id}" vClass="{veh["vClass"]}" accel="{veh["accel"]}" decel="{veh["decel"]}" sigma="{veh["sigma"]}" maxSpeed="{veh["maxSpeed"]}">\n'
        xml += '\t<param key="device.rerouting.probability" value="1.0"/>\n'
        xml += '\t<param key="device.rerouting.adaptation-steps" value="18"/>\n'
        xml += '\t<param key="device.rerouting.adaptation-interval" value="10"/>\n'
        xml += '</vType>\n'

    xml += '\n'
    xml += '<!-- Trips -->\n'
    for i in range(len(location_time_list)):
        path, stop_durations = getPath(location_time_list[i], parkingAreas)
        xml += pathToXML(path, f'veh{i + 1}', veh_types_per_student[i], departure_times[i], stop_durations) + '\n'
    xml += '</routes>'
    with open('PATHGEN.trips.xml', 'w') as f:
        f.write(xml)
    return xml

# %%
departure_times = []
for i in range(len(location_time_list)):
    departure_times.append((list(location_time_list[i].keys())[0] - 7) * 20)

veh_types = {'veh_passenger': {'vClass': 'passenger', 'accel': 2, 'decel': 5, 'sigma': 0.5, 'maxSpeed': 50}} # This is going to be a complete description of every vehicle, still have to choose what
                                                                                                                     # are going to be the parameters
veh_types_per_student = []
for i in range(len(location_time_list)):
    veh_types_per_student.append('veh_passenger')

xml = parseTripXML(location_time_list, parkingAreas, departure_times, veh_types, veh_types_per_student)
print(xml)
# Out:
# No edges found for -22.820626, -47.077545
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 11
#       8 for i in range(len(location_time_list)):
#       9     veh_types_per_student.append('veh_passenger')
# ---> 11 xml = parseTripXML(location_time_list, parkingAreas, departure_times, veh_types, veh_types_per_student)
#      12 print(xml)
#
# Cell In[19], line 20, in parseTripXML(location_time_list, parkingAreas, departure_times, veh_types, veh_types_per_student)
#      18 xml += '<!-- Trips -->\n'
#      19 for i in range(len(location_time_list)):
# ---> 20     path, stop_durations = getPath(location_time_list[i], parkingAreas)
#      21     xml += pathToXML(path, f'veh{i + 1}', veh_types_per_student[i], departure_times[i], stop_durations) + '\n'
#      22 xml += '</routes>'
#
# Cell In[11], line 17, in getPath(location_time_list, parkingAreas)
#      15 path = []
#      16 locations = list(location_time_list.values())
# ---> 17 home = getClosestEdges(*locations[0], radius)[0].getID()
#      18 path.append(home)
#      20 for i in range(1, len(locations)-1):
#
# IndexError: list index out of range

# %% [markdown]
# Getting alternative routes for every route found

# %%
# Run the duarouter to find alternative routes
# Currently this only works for less than 10 iterations
def getAltRoutes(net_path, trips_path, additional_path, iterations):
    for file in os.listdir('.'):
        if file.startswith('PATHGEN_') and file.endswith('.rou.alt.xml'):
            os.remove(file)
    
    try:
        subprocess.run(['python3', duaiterate_path] + getArgs(net_path, trips_path, additional_path, iterations), check=True)
        shutil.move(f'00{iterations-1}/osm.passenger_00{iterations-1}.rou.alt.xml', f'osm.passenger.rou.alt.xml')
        for i in range(iterations):
            if os.path.exists(f'00{i}'):
                shutil.rmtree(f'00{i}')
        for file in os.listdir('.'):
            if file.startswith('PATHGEN_') and file.endswith('.rou.alt.xml'):
                os.rename(file, f'PATHGEN.rou.alt.xml')
    except subprocess.CalledProcessError as e:
        print(f"{e}")

# %%
getAltRoutes('osm.net.xml', 'osm.passenger.trips.xml', 'park.add.xml', 5)
# Out:
# > Executing step 0
# >> Running router on osm.passenger.trips.xml
# >>> Begin time: 2024-10-18 13:59:34.208238
# >>> End time: 2024-10-18 13:59:36.610907
# >>> Duration: 0:00:02.402669
# <<
# >> Running simulation
# >>> Begin time: 2024-10-18 13:59:36.610978
# >>> End time: 2024-10-18 13:59:43.292614
# >>> Duration: 0:00:06.681636
# <<
# < Step 0 ended (duration: 0:00:09.091545)
# ------------------
#
# > Executing step 1
# >> Running router on 000/osm.passenger_000.rou.alt.xml
# >>> Begin time: 2024-10-18 13:59:43.313096
# >>> End time: 2024-10-18 13:59:45.266309
# >>> Duration: 0:00:01.953213
# <<
# >> Running simulation
# >>> Begin time: 2024-10-18 13:59:45.266375
# >>> End time: 2024-10-18 13:59:50.212720
# >>> Duration: 0:00:04.946345
# <<
# < Step 1 ended (duration: 0:00:06.901931)
# ------------------
#
# > Executing step 2
# >> Running router on 001/osm.passenger_001.rou.alt.xml
# >>> Begin time: 2024-10-18 13:59:50.224176
# >>> End time: 2024-10-18 13:59:52.068512
# >>> Duration: 0:00:01.844336
# <<
# >> Running simulation
# >>> Begin time: 2024-10-18 13:59:52.068599
# >>> End time: 2024-10-18 13:59:56.482184
# >>> Duration: 0:00:04.413585
# <<
# < Step 2 ended (duration: 0:00:06.259424)
# ------------------
#
# > Executing step 3
# >> Running router on 002/osm.passenger_002.rou.alt.xml
# >>> Begin time: 2024-10-18 13:59:56.492260
# >>> End time: 2024-10-18 13:59:58.335693
# >>> Duration: 0:00:01.843433
# <<
# >> Running simulation
# >>> Begin time: 2024-10-18 13:59:58.335769
# >>> End time: 2024-10-18 14:00:02.531394
# >>> Duration: 0:00:04.195625
# <<
# < Step 3 ended (duration: 0:00:06.039296)
# ------------------
#
# > Executing step 4
# >> Running router on 003/osm.passenger_003.rou.alt.xml
# >>> Begin time: 2024-10-18 14:00:02.538562
# >>> End time: 2024-10-18 14:00:04.306179
# >>> Duration: 0:00:01.767617
# <<
# >> Running simulation
# >>> Begin time: 2024-10-18 14:00:04.306236
# >>> End time: 2024-10-18 14:00:08.523845
# >>> Duration: 0:00:04.217609
# <<
# < Step 4 ended (duration: 0:00:05.985403)
# ------------------
#
# dua-iterate ended (duration: 0:00:34.321229)

# %% [markdown]
# To use this file, just set PATHGEN.rou.alt.xml as a trips file in osm.sumocfg
